# %%
# !pip install boto3
# !pip install python-dotenv
# Out:
# Requirement already satisfied: boto3 in /usr/local/lib/python3.11/dist-packages (1.37.28)
# Requirement already satisfied: botocore<1.38.0,>=1.37.28 in /usr/local/lib/python3.11/dist-packages (from boto3) (1.37.28)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from boto3) (0.11.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.28->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.28->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.28->boto3) (1.17.0)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.0

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="/content/env")
# Out:
# True

# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
from peft import LoraConfig, get_peft_model
from tqdm import tqdm
import boto3
import tempfile
import random

# %%
# ==== Step 0: Initialize Environment: Support for Multi-GPU and Single-GPU in Colab ====
is_distributed = "RANK" in os.environ and "WORLD_SIZE" in os.environ
if is_distributed:
    import torch.distributed as dist
    from torch.nn.parallel import DistributedDataParallel as DDP
    dist.init_process_group(backend="nccl")
    local_rank = int(os.environ["LOCAL_RANK"])
    torch.cuda.set_device(local_rank)
    device = torch.device("cuda", local_rank)
else:
    local_rank = 0
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
## ==== Step 1: Custom Dataset to Load .pt Files from S3 ====
# class S3PTVideoDataset(Dataset):
#     def __init__(self, s3_bucket, s3_prefix):
#         self.s3 = boto3.client(
#             's3',
#             aws_access_key_id="AKIAZOZQF46DEYT2U2VU",
#             aws_secret_access_key="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"
#         )
#         self.bucket = s3_bucket
#         self.prefix = s3_prefix
#         response = self.s3.list_objects_v2(Bucket=self.bucket, Prefix=self.prefix)
#         self.keys = [item['Key'] for item in response.get('Contents', []) if item['Key'].endswith(".pt")]

#     def __len__(self):
#         return len(self.keys)

#     def __getitem__(self, idx):
#         key = self.keys[idx]
#         with tempfile.NamedTemporaryFile(suffix=".pt") as temp:
#             self.s3.download_file(self.bucket, key, temp.name)
#             sample = torch.load(temp.name)
#         return sample["video"], sample["text"]

# %%
# ==== Step 1: Custom Dataset to Load .pt Files from S3 ====
from torch.utils.data import Dataset
import boto3
import tempfile
import torch

class S3PTVideoDataset(Dataset):
    def __init__(self, s3_bucket, s3_prefix):
        self.s3 = boto3.client(
            's3',
            aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
            aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY")
        )
        self.bucket = s3_bucket
        self.prefix = s3_prefix

        #  Use a Paginator to Retrieve All Keys
        paginator = self.s3.get_paginator('list_objects_v2')
        page_iterator = paginator.paginate(Bucket=self.bucket, Prefix=self.prefix)

        self.keys = []
        for page in page_iterator:
            if 'Contents' in page:
                self.keys.extend([item['Key'] for item in page['Contents'] if item['Key'].endswith('.pt')])

    def __len__(self):
        return len(self.keys)

    def __getitem__(self, idx):
        key = self.keys[idx]
        with tempfile.NamedTemporaryFile(suffix=".pt") as temp:
            self.s3.download_file(self.bucket, key, temp.name)
            sample = torch.load(temp.name)
        return sample["video"], sample["text"]

# %%
# ==== Step 2: Load Pretrained Model + Insert LoRA Layers ====
model_id = "damo-vilab/text-to-video-ms-1.7b"
pipe = DiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16, variant="fp16")
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.text_encoder.to(device)
pipe.tokenizer
pipe.vae.to(device)
pipe.unet.requires_grad_(False)
lora_config = LoraConfig(
    r=4,
    lora_alpha=16,
    target_modules=["to_q", "to_v"],
    bias="none"
)
pipe.unet = get_peft_model(pipe.unet, lora_config)
pipe.unet.to(device)
if is_distributed:
    pipe.unet = DDP(pipe.unet, device_ids=[local_rank])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# model.fp16.safetensors:   0%|          | 0.00/681M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/755 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/644 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/787 [00:00<?, ?B/s]
# diffusion_pytorch_model.fp16.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/657 [00:00<?, ?B/s]
# diffusion_pytorch_model.fp16.safetensors:   0%|          | 0.00/2.82G [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# ==== Step 3: Load Dataset (from S3) ====
s3_bucket = "data298youcook2"
s3_prefix = "ModelScope_T2V_processed_data/train"
dataset = S3PTVideoDataset(s3_bucket, s3_prefix)
if is_distributed:
    from torch.utils.data import DistributedSampler
    sampler = DistributedSampler(dataset)
else:
    sampler = None

dataloader = DataLoader(dataset, batch_size=2, shuffle=(sampler is None), sampler=sampler)

# %%
# # ==== Step 3.5: Download Last 3-Epoch Checkpoint from S3 ====
# s3 = boto3.client(
#     's3',
#     aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
#     aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY")
# )
# s3_bucket = "data298youcook2"
# s3_key = "ModelScope_T2V_finetuned/uniform_3epoch_123.pt"
# resume_path = "checkpoints/last_checkpoint.pt"

# if not os.path.exists(resume_path):
#     os.makedirs("checkpoints", exist_ok=True)
#     print(" Downloading uniform_3epoch_123.pt from S3...")
#     s3.download_file(s3_bucket, s3_key, resume_path)
#     print(" Download complete.")

# %%
#  Batch Sampling Function
def sample_segment_frames_batch(video_batch, num_frames=16, method="uniform"):
    """
    Sample a fixed number of frames from each video in a batch.

    Args:
        video_batch (Tensor): Input video tensor of shape [B, T, C, H, W]
        num_frames (int): Number of frames to sample per video
        method (str): Sampling strategy - "uniform", "center", or "random"

    Returns:
        Tensor: Output tensor of shape [B, num_frames, C, H, W]
    """
    B, T, C, H, W = video_batch.shape
    sampled = []

    for i in range(B):
        video = video_batch[i]
        if T <= num_frames:
            sampled_video = video
        else:
            if method == "uniform":
                indices = torch.linspace(0, T - 1, num_frames).long()
            elif method == "center":
                start = (T - num_frames) // 2
                indices = torch.arange(start, start + num_frames)
            elif method == "random":
                start = random.randint(0, T - num_frames)
                indices = torch.arange(start, start + num_frames)
            else:
                raise ValueError(f"Unsupported method: {method}")
            sampled_video = video[indices]
        sampled.append(sampled_video)

    return torch.stack(sampled)

# %% [markdown]
# Fine-tuning 3 epoch

# %%
from peft import get_peft_model_state_dict

# ==== Step 4: Training Loop + Checkpoint Saving ====
optimizer = torch.optim.Adam(pipe.unet.parameters(), lr=1e-4)
pipe.unet.train()

save_dir = "checkpoints"
os.makedirs(save_dir, exist_ok=True)
resume_path = os.path.join(save_dir, "last_checkpoint.pt")
if os.path.exists(resume_path):
    map_location = {f"cuda:{0}": f"cuda:{local_rank}"}
    state_dict = torch.load(resume_path, map_location=map_location)
    if is_distributed:
        pipe.unet.module.load_state_dict(state_dict)
    else:
        pipe.unet.load_state_dict(state_dict)

accumulate_steps = 2
scaler = torch.amp.GradScaler('cuda')

for epoch in range(2):
    if is_distributed:
        sampler.set_epoch(epoch)
    optimizer.zero_grad()

    running_loss = 0.0  #  For tracking average loss this epoch

    for step, (video, text) in enumerate(tqdm(dataloader, desc=f"Epoch {epoch+1} [Rank {local_rank}]")):
        video = video.to(device)  # [B, T, C, H, W]
        B, T, C, H, W = video.shape

        #  Sample frames from video
        video = sample_segment_frames_batch(video, num_frames=16, method="uniform")
        B, T, C, H, W = video.shape

        #  Tokenize text
        text_inputs = pipe.tokenizer(list(text), return_tensors="pt", padding=True, truncation=True).to(device)
        encoder_hidden_states = pipe.text_encoder(**text_inputs)[0]  # [B, L, D]

        #  VAE encoding
        video_flat = video.view(B * T, C, H, W)
        with torch.no_grad():
            latents_flat = pipe.vae.encode(video_flat).latent_dist.sample()

        latents = latents_flat.view(B, T, -1, H // 8, W // 8) * 0.18215
        latents = latents.permute(0, 2, 1, 3, 4)  # [B, C, T, H, W]

        #  Add noise
        noise = torch.randn_like(latents)
        timesteps = torch.randint(0, 1000, (B,), device=latents.device).long()
        noisy_latents = pipe.scheduler.add_noise(latents, noise, timesteps)

        #  Forward + loss
        with torch.amp.autocast('cuda'):
            noise_pred = pipe.unet(
                noisy_latents,
                timesteps,
                encoder_hidden_states=encoder_hidden_states
            ).sample
            loss = torch.nn.functional.mse_loss(noise_pred, noise) / accumulate_steps

        #  Backward
        scaler.scale(loss).backward()
        running_loss += loss.item()  #  Accumulate loss for this epoch

        if (step + 1) % accumulate_steps == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        # Save LoRA adapter weights
        if step % 100 == 0 and local_rank == 0:
            ckpt_path = os.path.join(save_dir, f"epoch{epoch+1}_step{step}.pt")
            lora_state_dict = get_peft_model_state_dict(pipe.unet)
            torch.save(lora_state_dict, ckpt_path)
            torch.save(lora_state_dict, resume_path)
            print(f" Saved LoRA-only checkpoint: {ckpt_path}")

    torch.cuda.empty_cache()

    #  Print epoch average loss (only on main process)
    avg_loss = running_loss / len(dataloader)
    if local_rank == 0:
        print(f" [Epoch {epoch+1}] Average Loss: {avg_loss:.6f}")
# Out:
# Epoch 1 [Rank 0]:   0%|          | 1/4270 [00:06<8:16:52,  6.98s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step0.pt
# Epoch 1 [Rank 0]:   2%|▏         | 101/4270 [03:29<2:56:32,  2.54s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step100.pt
# Epoch 1 [Rank 0]:   5%|▍         | 201/4270 [07:18<2:51:08,  2.52s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step200.pt
# Epoch 1 [Rank 0]:   7%|▋         | 301/4270 [10:44<2:52:27,  2.61s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step300.pt
# Epoch 1 [Rank 0]:   9%|▉         | 401/4270 [14:10<2:33:48,  2.39s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step400.pt
# Epoch 1 [Rank 0]:  12%|█▏        | 501/4270 [17:49<2:34:58,  2.47s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step500.pt
# Epoch 1 [Rank 0]:  14%|█▍        | 601/4270 [22:59<5:27:12,  5.35s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step600.pt
# Epoch 1 [Rank 0]:  16%|█▋        | 701/4270 [29:40<2:08:30,  2.16s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step700.pt
# Epoch 1 [Rank 0]:  19%|█▉        | 801/4270 [33:13<2:12:08,  2.29s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step800.pt
# Epoch 1 [Rank 0]:  21%|██        | 901/4270 [36:59<1:49:57,  1.96s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step900.pt
# Epoch 1 [Rank 0]:  23%|██▎       | 1001/4270 [40:27<1:45:55,  1.94s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step1000.pt
# Epoch 1 [Rank 0]:  26%|██▌       | 1101/4270 [43:52<1:50:56,  2.10s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step1100.pt
# Epoch 1 [Rank 0]:  28%|██▊       | 1201/4270 [47:19<1:47:56,  2.11s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step1200.pt
# Epoch 1 [Rank 0]:  30%|███       | 1301/4270 [50:47<1:40:07,  2.02s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step1300.pt
# Epoch 1 [Rank 0]:  33%|███▎      | 1401/4270 [54:53<1:34:46,  1.98s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step1400.pt
# Epoch 1 [Rank 0]:  35%|███▌      | 1501/4270 [58:17<1:35:34,  2.07s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step1500.pt
# Epoch 1 [Rank 0]:  37%|███▋      | 1601/4270 [1:02:08<1:57:24,  2.64s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step1600.pt
# Epoch 1 [Rank 0]:  40%|███▉      | 1701/4270 [1:05:41<1:29:39,  2.09s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step1700.pt
# Epoch 1 [Rank 0]:  42%|████▏     | 1801/4270 [1:09:19<2:22:44,  3.47s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step1800.pt
# Epoch 1 [Rank 0]:  45%|████▍     | 1901/4270 [1:13:49<1:24:16,  2.13s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step1900.pt
# Epoch 1 [Rank 0]:  47%|████▋     | 2001/4270 [1:17:17<1:17:12,  2.04s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step2000.pt
# Epoch 1 [Rank 0]:  49%|████▉     | 2101/4270 [1:20:42<1:14:21,  2.06s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step2100.pt
# Epoch 1 [Rank 0]:  52%|█████▏    | 2201/4270 [1:24:09<1:06:26,  1.93s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step2200.pt
# Epoch 1 [Rank 0]:  54%|█████▍    | 2301/4270 [1:27:30<1:04:52,  1.98s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step2300.pt
# Epoch 1 [Rank 0]:  56%|█████▌    | 2401/4270 [1:31:16<58:11,  1.87s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step2400.pt
# Epoch 1 [Rank 0]:  59%|█████▊    | 2501/4270 [1:34:36<56:34,  1.92s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step2500.pt
# Epoch 1 [Rank 0]:  61%|██████    | 2601/4270 [1:38:00<52:38,  1.89s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step2600.pt
# Epoch 1 [Rank 0]:  63%|██████▎   | 2701/4270 [1:41:33<56:23,  2.16s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step2700.pt
# Epoch 1 [Rank 0]:  66%|██████▌   | 2801/4270 [1:44:51<47:04,  1.92s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step2800.pt
# Epoch 1 [Rank 0]:  68%|██████▊   | 2901/4270 [1:48:15<48:07,  2.11s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step2900.pt
# Epoch 1 [Rank 0]:  70%|███████   | 3001/4270 [1:52:05<54:59,  2.60s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step3000.pt
# Epoch 1 [Rank 0]:  73%|███████▎  | 3101/4270 [1:55:42<41:23,  2.12s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step3100.pt
# Epoch 1 [Rank 0]:  75%|███████▍  | 3201/4270 [1:59:22<38:09,  2.14s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step3200.pt
# Epoch 1 [Rank 0]:  77%|███████▋  | 3301/4270 [2:02:47<31:10,  1.93s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step3300.pt
# Epoch 1 [Rank 0]:  80%|███████▉  | 3401/4270 [2:08:06<27:37,  1.91s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step3400.pt
# Epoch 1 [Rank 0]:  82%|████████▏ | 3501/4270 [2:11:39<31:31,  2.46s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step3500.pt
# Epoch 1 [Rank 0]:  84%|████████▍ | 3601/4270 [2:15:09<21:52,  1.96s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step3600.pt
# Epoch 1 [Rank 0]:  87%|████████▋ | 3701/4270 [2:18:48<18:40,  1.97s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step3700.pt
# Epoch 1 [Rank 0]:  89%|████████▉ | 3801/4270 [2:22:25<15:12,  1.95s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step3800.pt
# Epoch 1 [Rank 0]:  91%|█████████▏| 3901/4270 [2:25:56<13:38,  2.22s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step3900.pt
# Epoch 1 [Rank 0]:  94%|█████████▎| 4001/4270 [2:29:19<08:44,  1.95s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step4000.pt
# Epoch 1 [Rank 0]:  96%|█████████▌| 4101/4270 [2:32:41<05:27,  1.94s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step4100.pt
# Epoch 1 [Rank 0]:  98%|█████████▊| 4201/4270 [2:36:19<02:16,  1.98s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch1_step4200.pt
# Epoch 1 [Rank 0]: 100%|██████████| 4270/4270 [2:38:39<00:00,  2.23s/it]
# ✅ [Epoch 1] Average Loss: 0.053736
# Epoch 2 [Rank 0]:   0%|          | 1/4270 [00:02<2:32:48,  2.15s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step0.pt
# Epoch 2 [Rank 0]:   2%|▏         | 101/4270 [03:24<2:22:49,  2.06s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step100.pt
# Epoch 2 [Rank 0]:   5%|▍         | 201/4270 [06:49<2:15:06,  1.99s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step200.pt
# Epoch 2 [Rank 0]:   7%|▋         | 301/4270 [10:12<2:05:11,  1.89s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step300.pt
# Epoch 2 [Rank 0]:   9%|▉         | 401/4270 [13:32<2:01:36,  1.89s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step400.pt
# Epoch 2 [Rank 0]:  12%|█▏        | 501/4270 [16:58<2:16:36,  2.17s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step500.pt
# Epoch 2 [Rank 0]:  14%|█▍        | 601/4270 [20:38<1:59:45,  1.96s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step600.pt
# Epoch 2 [Rank 0]:  16%|█▋        | 701/4270 [24:08<2:08:54,  2.17s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step700.pt
# Epoch 2 [Rank 0]:  19%|█▉        | 801/4270 [27:58<2:29:57,  2.59s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step800.pt
# Epoch 2 [Rank 0]:  21%|██        | 901/4270 [31:28<1:54:36,  2.04s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step900.pt
# Epoch 2 [Rank 0]:  23%|██▎       | 1001/4270 [38:18<2:02:25,  2.25s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step1000.pt
# Epoch 2 [Rank 0]:  26%|██▌       | 1101/4270 [41:44<1:56:13,  2.20s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step1100.pt
# Epoch 2 [Rank 0]:  28%|██▊       | 1201/4270 [45:09<2:04:05,  2.43s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step1200.pt
# Epoch 2 [Rank 0]:  30%|███       | 1301/4270 [48:32<1:49:23,  2.21s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step1300.pt
# Epoch 2 [Rank 0]:  33%|███▎      | 1401/4270 [51:58<1:46:21,  2.22s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step1400.pt
# Epoch 2 [Rank 0]:  35%|███▌      | 1501/4270 [55:32<1:50:47,  2.40s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step1500.pt
# Epoch 2 [Rank 0]:  37%|███▋      | 1601/4270 [58:51<1:35:17,  2.14s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step1600.pt
# Epoch 2 [Rank 0]:  40%|███▉      | 1701/4270 [1:02:18<1:35:23,  2.23s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step1700.pt
# Epoch 2 [Rank 0]:  42%|████▏     | 1801/4270 [1:06:20<1:33:27,  2.27s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step1800.pt
# Epoch 2 [Rank 0]:  45%|████▍     | 1901/4270 [1:09:55<1:29:00,  2.25s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step1900.pt
# Epoch 2 [Rank 0]:  47%|████▋     | 2001/4270 [1:13:21<1:24:15,  2.23s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step2000.pt
# Epoch 2 [Rank 0]:  49%|████▉     | 2101/4270 [1:17:26<1:49:55,  3.04s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step2100.pt
# Epoch 2 [Rank 0]:  52%|█████▏    | 2201/4270 [1:20:49<1:19:28,  2.30s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step2200.pt
# Epoch 2 [Rank 0]:  54%|█████▍    | 2301/4270 [1:24:13<1:15:43,  2.31s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step2300.pt
# Epoch 2 [Rank 0]:  56%|█████▌    | 2401/4270 [1:27:41<1:08:27,  2.20s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step2400.pt
# Epoch 2 [Rank 0]:  59%|█████▊    | 2501/4270 [1:31:25<1:07:32,  2.29s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step2500.pt
# Epoch 2 [Rank 0]:  61%|██████    | 2601/4270 [1:34:48<1:01:07,  2.20s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step2600.pt
# Epoch 2 [Rank 0]:  63%|██████▎   | 2701/4270 [1:38:17<57:29,  2.20s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step2700.pt
# Epoch 2 [Rank 0]:  66%|██████▌   | 2801/4270 [1:41:48<55:06,  2.25s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step2800.pt
# Epoch 2 [Rank 0]:  68%|██████▊   | 2901/4270 [1:46:32<55:46,  2.44s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step2900.pt
# Epoch 2 [Rank 0]:  70%|███████   | 3001/4270 [1:50:14<45:09,  2.14s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step3000.pt
# Epoch 2 [Rank 0]:  73%|███████▎  | 3101/4270 [1:53:37<40:12,  2.06s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step3100.pt
# Epoch 2 [Rank 0]:  75%|███████▍  | 3201/4270 [1:56:58<34:05,  1.91s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step3200.pt
# Epoch 2 [Rank 0]:  77%|███████▋  | 3301/4270 [2:00:24<33:02,  2.05s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step3300.pt
# Epoch 2 [Rank 0]:  80%|███████▉  | 3401/4270 [2:03:51<30:04,  2.08s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step3400.pt
# Epoch 2 [Rank 0]:  82%|████████▏ | 3501/4270 [2:08:08<24:19,  1.90s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step3500.pt
# Epoch 2 [Rank 0]:  84%|████████▍ | 3601/4270 [2:11:31<24:29,  2.20s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step3600.pt
# Epoch 2 [Rank 0]:  87%|████████▋ | 3701/4270 [2:15:03<18:13,  1.92s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step3700.pt
# Epoch 2 [Rank 0]:  89%|████████▉ | 3801/4270 [2:18:25<16:15,  2.08s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step3800.pt
# Epoch 2 [Rank 0]:  91%|█████████▏| 3901/4270 [2:23:57<14:27,  2.35s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step3900.pt
# Epoch 2 [Rank 0]:  94%|█████████▎| 4001/4270 [2:27:42<09:07,  2.04s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step4000.pt
# Epoch 2 [Rank 0]:  96%|█████████▌| 4101/4270 [2:31:22<05:41,  2.02s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step4100.pt
# Epoch 2 [Rank 0]:  98%|█████████▊| 4201/4270 [2:34:50<02:18,  2.00s/it]
# 💾 Saved LoRA-only checkpoint: checkpoints/epoch2_step4200.pt
# Epoch 2 [Rank 0]: 100%|██████████| 4270/4270 [2:37:41<00:00,  2.22s/it]
# ✅ [Epoch 2] Average Loss: 0.048320

# %%
import os
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
from peft import LoraConfig, get_peft_model, get_peft_model_state_dict
from tqdm import tqdm
import boto3
import tempfile
import random

# ==== Distributed Support (Colab defaults to single GPU) ====
is_distributed = "RANK" in os.environ and "WORLD_SIZE" in os.environ
if is_distributed:
    import torch.distributed as dist
    from torch.nn.parallel import DistributedDataParallel as DDP
    dist.init_process_group(backend="nccl")
    local_rank = int(os.environ["LOCAL_RANK"])
    torch.cuda.set_device(local_rank)
    device = torch.device("cuda", local_rank)
else:
    local_rank = 0
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ==== S3 Dataset ====
class S3PTVideoDataset(Dataset):
    def __init__(self, s3_bucket, s3_prefix):
        self.s3 = boto3.client(
            's3',
            aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
            aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY")
        )
        self.bucket = s3_bucket
        self.prefix = s3_prefix

        paginator = self.s3.get_paginator('list_objects_v2')
        page_iterator = paginator.paginate(Bucket=self.bucket, Prefix=self.prefix)

        self.keys = []
        for page in page_iterator:
            if 'Contents' in page:
                self.keys.extend([item['Key'] for item in page['Contents'] if item['Key'].endswith('.pt')])

    def __len__(self):
        return len(self.keys)

    def __getitem__(self, idx):
        key = self.keys[idx]
        with tempfile.NamedTemporaryFile(suffix=".pt") as temp:
            self.s3.download_file(self.bucket, key, temp.name)
            sample = torch.load(temp.name)
        return sample["video"], sample["text"]

# ==== Video Frame Sampling + Resize ====
def sample_segment_frames_batch(video_batch, num_frames=8, method="uniform", target_size=(128, 128)):
    B, T, C, H, W = video_batch.shape
    sampled = []

    for i in range(B):
        video = video_batch[i]
        if T <= num_frames:
            sampled_video = video
        else:
            if method == "uniform":
                indices = torch.linspace(0, T - 1, num_frames).long()
            else:
                start = random.randint(0, T - num_frames)
                indices = torch.arange(start, start + num_frames)
            sampled_video = video[indices]
        #  Resize
        sampled_video = F.interpolate(sampled_video, size=target_size, mode='bilinear', align_corners=False)
        sampled.append(sampled_video)

    return torch.stack(sampled)

# ==== Load Model + LoRA ====
model_id = "damo-vilab/text-to-video-ms-1.7b"
pipe = DiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16, variant="fp16")
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)

pipe.vae.to(device)
pipe.text_encoder.to(device)
pipe.text_encoder.eval()
for p in pipe.text_encoder.parameters():
    p.requires_grad = False

pipe.unet.requires_grad_(False)
lora_config = LoraConfig(
    r=4,
    lora_alpha=16,
    target_modules=["to_q", "to_v"],
    bias="none"
)
pipe.unet = get_peft_model(pipe.unet, lora_config)
pipe.unet.to(device)

if is_distributed:
    pipe.unet = DDP(pipe.unet, device_ids=[local_rank])

# ==== Load Dataset ====
s3_bucket = "data298youcook2"
s3_prefix = "ModelScope_T2V_processed_data/train"
dataset = S3PTVideoDataset(s3_bucket, s3_prefix)

sampler = DistributedSampler(dataset) if is_distributed else None
dataloader = DataLoader(
    dataset,
    batch_size=1,
    shuffle=(sampler is None),
    sampler=sampler,
    pin_memory=True,
    num_workers=2
)

# ==== Training Setup ====
save_dir = "checkpoints"
resume_path = os.path.join(save_dir, "last_checkpoint.pt")
total_epochs = 5
start_epoch = 2
accumulate_steps = 4
os.makedirs(save_dir, exist_ok=True)

optimizer = torch.optim.Adam(pipe.unet.parameters(), lr=1e-4)
scaler = torch.cuda.amp.GradScaler()
pipe.unet.train()

# ==== Resume LoRA Weights ====
if os.path.exists(resume_path):
    print(f" Resuming from checkpoint: {resume_path}")
    map_location = {f"cuda:0": f"cuda:{local_rank}"}
    lora_state_dict = torch.load(resume_path, map_location=map_location)
    if is_distributed:
        pipe.unet.module.load_state_dict(lora_state_dict, strict=False)
    else:
        pipe.unet.load_state_dict(lora_state_dict, strict=False)
    print(" LoRA adapter weights loaded.")
else:
    print(" Starting fresh training.")

# ==== Training Loop ====
for epoch in range(start_epoch, total_epochs):
    if is_distributed:
        sampler.set_epoch(epoch)

    optimizer.zero_grad()
    running_loss = 0.0

    for step, (video, text) in enumerate(tqdm(dataloader, desc=f"Epoch {epoch+1} [Rank {local_rank}]")):
        video = video.to(device)
        B, T, C, H, W = video.shape
        video = sample_segment_frames_batch(video, num_frames=8)

        text_inputs = pipe.tokenizer(list(text), return_tensors="pt", padding=True, truncation=True).to(device)
        encoder_hidden_states = pipe.text_encoder(**text_inputs)[0]

        with torch.no_grad():
            video_flat = video.view(B * 8, C, 128, 128)
            latents_flat = pipe.vae.encode(video_flat).latent_dist.sample()

        latents = latents_flat.view(B, 8, -1, 16, 16) * 0.18215
        latents = latents.permute(0, 2, 1, 3, 4)
        noise = torch.randn_like(latents)
        timesteps = torch.randint(0, 1000, (B,), device=latents.device).long()
        noisy_latents = pipe.scheduler.add_noise(latents, noise, timesteps)

        with torch.cuda.amp.autocast():
            noise_pred = pipe.unet(noisy_latents, timesteps, encoder_hidden_states=encoder_hidden_states).sample
            loss = torch.nn.functional.mse_loss(noise_pred, noise) / accumulate_steps

        scaler.scale(loss).backward()
        running_loss += loss.item()

        if (step + 1) % accumulate_steps == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        if step % 100 == 0 and local_rank == 0:
            ckpt_path = os.path.join(save_dir, f"epoch{epoch+1}_step{step}.pt")
            torch.save(get_peft_model_state_dict(pipe.unet), ckpt_path)
            torch.save(get_peft_model_state_dict(pipe.unet), resume_path)
            print(f" Saved LoRA-only checkpoint: {ckpt_path}")

    torch.cuda.empty_cache()
    avg_loss = running_loss / len(dataloader)
    if local_rank == 0:
        print(f" [Epoch {epoch+1}] Average Loss: {avg_loss:.6f}")
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# <ipython-input-12-8f695578225b>:124: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#  Resuming from checkpoint: checkpoints/last_checkpoint.pt
#  LoRA adapter weights loaded.
# Epoch 3 [Rank 0]:   0%|          | 0/8539 [00:00<?, ?it/s]<ipython-input-12-8f695578225b>:166: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 3 [Rank 0]:   0%|          | 1/8539 [00:04<10:47:22,  4.55s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step0.pt
# Epoch 3 [Rank 0]:   1%|          | 101/8539 [00:43<2:02:55,  1.14it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step100.pt
# Epoch 3 [Rank 0]:   2%|▏         | 201/8539 [01:33<1:22:04,  1.69it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step200.pt
# Epoch 3 [Rank 0]:   4%|▎         | 301/8539 [02:12<1:29:23,  1.54it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step300.pt
# Epoch 3 [Rank 0]:   5%|▍         | 401/8539 [02:51<1:27:33,  1.55it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step400.pt
# Epoch 3 [Rank 0]:   6%|▌         | 501/8539 [03:29<1:31:37,  1.46it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step500.pt
# Epoch 3 [Rank 0]:   7%|▋         | 601/8539 [05:27<1:17:22,  1.71it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step600.pt
# Epoch 3 [Rank 0]:   8%|▊         | 701/8539 [06:09<1:37:16,  1.34it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step700.pt
# Epoch 3 [Rank 0]:   9%|▉         | 801/8539 [06:48<1:29:03,  1.45it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step800.pt
# Epoch 3 [Rank 0]:  11%|█         | 901/8539 [07:26<1:30:54,  1.40it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step900.pt
# Epoch 3 [Rank 0]:  12%|█▏        | 1001/8539 [08:09<1:51:36,  1.13it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step1000.pt
# Epoch 3 [Rank 0]:  13%|█▎        | 1101/8539 [08:46<1:52:47,  1.10it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step1100.pt
# Epoch 3 [Rank 0]:  14%|█▍        | 1201/8539 [09:49<1:27:36,  1.40it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step1200.pt
# Epoch 3 [Rank 0]:  15%|█▌        | 1301/8539 [11:08<2:03:13,  1.02s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step1300.pt
# Epoch 3 [Rank 0]:  16%|█▋        | 1401/8539 [11:50<1:14:55,  1.59it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step1400.pt
# Epoch 3 [Rank 0]:  18%|█▊        | 1501/8539 [12:30<1:42:23,  1.15it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step1500.pt
# Epoch 3 [Rank 0]:  19%|█▊        | 1601/8539 [13:09<2:24:42,  1.25s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step1600.pt
# Epoch 3 [Rank 0]:  20%|█▉        | 1701/8539 [15:32<2:32:26,  1.34s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step1700.pt
# Epoch 3 [Rank 0]:  21%|██        | 1801/8539 [16:10<1:20:00,  1.40it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step1800.pt
# Epoch 3 [Rank 0]:  22%|██▏       | 1901/8539 [16:53<1:45:34,  1.05it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step1900.pt
# Epoch 3 [Rank 0]:  23%|██▎       | 2001/8539 [17:32<1:34:05,  1.16it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step2000.pt
# Epoch 3 [Rank 0]:  25%|██▍       | 2101/8539 [18:28<1:52:02,  1.04s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step2100.pt
# Epoch 3 [Rank 0]:  26%|██▌       | 2201/8539 [19:06<1:33:06,  1.13it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step2200.pt
# Epoch 3 [Rank 0]:  27%|██▋       | 2301/8539 [19:47<1:33:04,  1.12it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step2300.pt
# Epoch 3 [Rank 0]:  28%|██▊       | 2401/8539 [20:25<1:26:03,  1.19it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step2400.pt
# Epoch 3 [Rank 0]:  29%|██▉       | 2501/8539 [21:05<1:27:47,  1.15it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step2500.pt
# Epoch 3 [Rank 0]:  30%|███       | 2601/8539 [22:41<43:35,  2.27it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step2600.pt
# Epoch 3 [Rank 0]:  32%|███▏      | 2701/8539 [23:20<38:22,  2.54it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step2700.pt
# Epoch 3 [Rank 0]:  33%|███▎      | 2801/8539 [24:33<1:16:04,  1.26it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step2800.pt
# Epoch 3 [Rank 0]:  34%|███▍      | 2901/8539 [25:13<40:27,  2.32it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step2900.pt
# Epoch 3 [Rank 0]:  35%|███▌      | 3001/8539 [26:04<51:23,  1.80it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step3000.pt
# Epoch 3 [Rank 0]:  36%|███▋      | 3101/8539 [26:57<51:47,  1.75it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step3100.pt
# Epoch 3 [Rank 0]:  37%|███▋      | 3201/8539 [27:36<36:11,  2.46it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step3200.pt
# Epoch 3 [Rank 0]:  39%|███▊      | 3301/8539 [28:16<35:46,  2.44it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step3300.pt
# Epoch 3 [Rank 0]:  40%|███▉      | 3401/8539 [28:52<31:48,  2.69it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step3400.pt
# Epoch 3 [Rank 0]:  41%|████      | 3501/8539 [29:32<33:56,  2.47it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step3500.pt
# Epoch 3 [Rank 0]:  42%|████▏     | 3601/8539 [30:09<30:17,  2.72it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step3600.pt
# Epoch 3 [Rank 0]:  43%|████▎     | 3701/8539 [31:01<44:42,  1.80it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step3700.pt
# Epoch 3 [Rank 0]:  45%|████▍     | 3801/8539 [31:39<34:51,  2.27it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step3800.pt
# Epoch 3 [Rank 0]:  46%|████▌     | 3901/8539 [32:15<28:18,  2.73it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step3900.pt
# Epoch 3 [Rank 0]:  47%|████▋     | 4001/8539 [32:54<27:31,  2.75it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step4000.pt
# Epoch 3 [Rank 0]:  48%|████▊     | 4101/8539 [33:31<26:48,  2.76it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step4100.pt
# Epoch 3 [Rank 0]:  49%|████▉     | 4201/8539 [34:23<41:16,  1.75it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step4200.pt
# Epoch 3 [Rank 0]:  50%|█████     | 4301/8539 [35:00<25:50,  2.73it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step4300.pt
# Epoch 3 [Rank 0]:  52%|█████▏    | 4401/8539 [35:59<1:13:41,  1.07s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step4400.pt
# Epoch 3 [Rank 0]:  53%|█████▎    | 4501/8539 [36:39<27:45,  2.42it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step4500.pt
# Epoch 3 [Rank 0]:  54%|█████▍    | 4601/8539 [37:14<26:26,  2.48it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step4600.pt
# Epoch 3 [Rank 0]:  55%|█████▌    | 4701/8539 [37:51<23:26,  2.73it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step4700.pt
# Epoch 3 [Rank 0]:  56%|█████▌    | 4801/8539 [38:29<22:53,  2.72it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step4800.pt
# Epoch 3 [Rank 0]:  57%|█████▋    | 4901/8539 [39:06<22:02,  2.75it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step4900.pt
# Epoch 3 [Rank 0]:  59%|█████▊    | 5001/8539 [39:42<21:45,  2.71it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step5000.pt
# Epoch 3 [Rank 0]:  60%|█████▉    | 5101/8539 [40:18<21:13,  2.70it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step5100.pt
# Epoch 3 [Rank 0]:  61%|██████    | 5201/8539 [40:54<21:11,  2.63it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step5200.pt
# Epoch 3 [Rank 0]:  62%|██████▏   | 5301/8539 [41:32<20:37,  2.62it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step5300.pt
# Epoch 3 [Rank 0]:  63%|██████▎   | 5401/8539 [42:10<19:02,  2.75it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step5400.pt
# Epoch 3 [Rank 0]:  64%|██████▍   | 5501/8539 [42:49<22:15,  2.27it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step5500.pt
# Epoch 3 [Rank 0]:  66%|██████▌   | 5601/8539 [43:31<18:46,  2.61it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step5600.pt
# Epoch 3 [Rank 0]:  67%|██████▋   | 5701/8539 [44:09<18:19,  2.58it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step5700.pt
# Epoch 3 [Rank 0]:  68%|██████▊   | 5801/8539 [44:47<17:14,  2.65it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step5800.pt
# Epoch 3 [Rank 0]:  69%|██████▉   | 5901/8539 [45:28<17:11,  2.56it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step5900.pt
# Epoch 3 [Rank 0]:  70%|███████   | 6001/8539 [46:06<16:42,  2.53it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step6000.pt
# Epoch 3 [Rank 0]:  71%|███████▏  | 6101/8539 [46:44<15:21,  2.65it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step6100.pt
# Epoch 3 [Rank 0]:  73%|███████▎  | 6201/8539 [47:24<15:41,  2.48it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step6200.pt
# Epoch 3 [Rank 0]:  74%|███████▍  | 6301/8539 [48:15<18:26,  2.02it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step6300.pt
# Epoch 3 [Rank 0]:  75%|███████▍  | 6401/8539 [48:55<13:50,  2.57it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step6400.pt
# Epoch 3 [Rank 0]:  76%|███████▌  | 6501/8539 [49:42<19:52,  1.71it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step6500.pt
# Epoch 3 [Rank 0]:  77%|███████▋  | 6601/8539 [50:20<12:55,  2.50it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step6600.pt
# Epoch 3 [Rank 0]:  78%|███████▊  | 6701/8539 [50:58<11:16,  2.72it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step6700.pt
# Epoch 3 [Rank 0]:  80%|███████▉  | 6801/8539 [51:38<11:33,  2.51it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step6800.pt
# Epoch 3 [Rank 0]:  81%|████████  | 6901/8539 [52:15<10:28,  2.61it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step6900.pt
# Epoch 3 [Rank 0]:  82%|████████▏ | 7001/8539 [53:08<15:31,  1.65it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step7000.pt
# Epoch 3 [Rank 0]:  83%|████████▎ | 7101/8539 [53:48<09:56,  2.41it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step7100.pt
# Epoch 3 [Rank 0]:  84%|████████▍ | 7201/8539 [54:25<08:18,  2.69it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step7200.pt
# Epoch 3 [Rank 0]:  86%|████████▌ | 7301/8539 [55:17<12:30,  1.65it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step7300.pt
# Epoch 3 [Rank 0]:  87%|████████▋ | 7401/8539 [55:57<08:04,  2.35it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step7400.pt
# Epoch 3 [Rank 0]:  88%|████████▊ | 7501/8539 [56:34<06:18,  2.74it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step7500.pt
# Epoch 3 [Rank 0]:  89%|████████▉ | 7601/8539 [57:13<06:12,  2.52it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step7600.pt
# Epoch 3 [Rank 0]:  90%|█████████ | 7701/8539 [58:05<07:50,  1.78it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step7700.pt
# Epoch 3 [Rank 0]:  91%|█████████▏| 7801/8539 [58:44<04:34,  2.69it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step7800.pt
# Epoch 3 [Rank 0]:  93%|█████████▎| 7901/8539 [59:21<03:54,  2.72it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step7900.pt
# Epoch 3 [Rank 0]:  94%|█████████▎| 8001/8539 [1:00:00<03:39,  2.45it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step8000.pt
# Epoch 3 [Rank 0]:  95%|█████████▍| 8101/8539 [1:00:44<03:49,  1.91it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step8100.pt
# Epoch 3 [Rank 0]:  96%|█████████▌| 8201/8539 [1:01:23<02:31,  2.23it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step8200.pt
# Epoch 3 [Rank 0]:  97%|█████████▋| 8301/8539 [1:02:04<01:37,  2.44it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step8300.pt
# Epoch 3 [Rank 0]:  98%|█████████▊| 8401/8539 [1:02:42<01:00,  2.30it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step8400.pt
# Epoch 3 [Rank 0]: 100%|█████████▉| 8501/8539 [1:03:20<00:14,  2.59it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch3_step8500.pt
# Epoch 3 [Rank 0]: 100%|██████████| 8539/8539 [1:03:40<00:00,  2.24it/s]
#  [Epoch 3] Average Loss: 0.037381
# Epoch 4 [Rank 0]:   0%|          | 1/8539 [00:03<7:26:06,  3.13s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step0.pt
# Epoch 4 [Rank 0]:   1%|          | 101/8539 [00:41<2:02:10,  1.15it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step100.pt
# Epoch 4 [Rank 0]:   2%|▏         | 201/8539 [01:31<1:22:38,  1.68it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step200.pt
# Epoch 4 [Rank 0]:   4%|▎         | 301/8539 [02:09<1:57:54,  1.16it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step300.pt
# Epoch 4 [Rank 0]:   5%|▍         | 401/8539 [02:48<2:00:06,  1.13it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step400.pt
# Epoch 4 [Rank 0]:   6%|▌         | 501/8539 [03:25<1:33:02,  1.44it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step500.pt
# Epoch 4 [Rank 0]:   7%|▋         | 601/8539 [04:01<1:27:35,  1.51it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step600.pt
# Epoch 4 [Rank 0]:   8%|▊         | 701/8539 [04:42<1:22:14,  1.59it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step700.pt
# Epoch 4 [Rank 0]:   9%|▉         | 801/8539 [05:21<1:50:41,  1.17it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step800.pt
# Epoch 4 [Rank 0]:  11%|█         | 901/8539 [05:59<1:49:59,  1.16it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step900.pt
# Epoch 4 [Rank 0]:  12%|█▏        | 1001/8539 [06:38<1:45:01,  1.20it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step1000.pt
# Epoch 4 [Rank 0]:  13%|█▎        | 1101/8539 [07:17<1:46:13,  1.17it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step1100.pt
# Epoch 4 [Rank 0]:  14%|█▍        | 1201/8539 [07:55<1:46:36,  1.15it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step1200.pt
# Epoch 4 [Rank 0]:  15%|█▌        | 1301/8539 [08:35<1:48:36,  1.11it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step1300.pt
# Epoch 4 [Rank 0]:  16%|█▋        | 1401/8539 [09:26<1:11:03,  1.67it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step1400.pt
# Epoch 4 [Rank 0]:  18%|█▊        | 1501/8539 [10:06<1:25:32,  1.37it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step1500.pt
# Epoch 4 [Rank 0]:  19%|█▊        | 1601/8539 [10:45<1:11:04,  1.63it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step1600.pt
# Epoch 4 [Rank 0]:  20%|█▉        | 1701/8539 [11:27<1:47:18,  1.06it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step1700.pt
# Epoch 4 [Rank 0]:  21%|██        | 1801/8539 [12:03<1:26:31,  1.30it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step1800.pt
# Epoch 4 [Rank 0]:  22%|██▏       | 1901/8539 [15:03<4:54:50,  2.67s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step1900.pt
# Epoch 4 [Rank 0]:  23%|██▎       | 2001/8539 [15:44<1:16:02,  1.43it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step2000.pt
# Epoch 4 [Rank 0]:  25%|██▍       | 2101/8539 [17:49<3:33:08,  1.99s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step2100.pt
# Epoch 4 [Rank 0]:  26%|██▌       | 2201/8539 [18:27<1:11:09,  1.48it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step2200.pt
# Epoch 4 [Rank 0]:  27%|██▋       | 2301/8539 [19:08<1:19:21,  1.31it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step2300.pt
# Epoch 4 [Rank 0]:  28%|██▊       | 2401/8539 [19:50<1:00:38,  1.69it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step2400.pt
# Epoch 4 [Rank 0]:  29%|██▉       | 2501/8539 [21:20<3:04:24,  1.83s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step2500.pt
# Epoch 4 [Rank 0]:  30%|███       | 2601/8539 [24:05<3:23:37,  2.06s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step2600.pt
# Epoch 4 [Rank 0]:  32%|███▏      | 2701/8539 [24:46<1:00:27,  1.61it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step2700.pt
# Epoch 4 [Rank 0]:  33%|███▎      | 2801/8539 [25:36<1:09:38,  1.37it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step2800.pt
# Epoch 4 [Rank 0]:  34%|███▍      | 2901/8539 [26:17<1:01:12,  1.54it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step2900.pt
# Epoch 4 [Rank 0]:  35%|███▌      | 3001/8539 [26:57<1:04:52,  1.42it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step3000.pt
# Epoch 4 [Rank 0]:  36%|███▋      | 3101/8539 [27:35<59:27,  1.52it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step3100.pt
# Epoch 4 [Rank 0]:  37%|███▋      | 3201/8539 [28:15<1:00:16,  1.48it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step3200.pt
# Epoch 4 [Rank 0]:  39%|███▊      | 3301/8539 [29:00<1:25:32,  1.02it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step3300.pt
# Epoch 4 [Rank 0]:  40%|███▉      | 3401/8539 [29:40<54:54,  1.56it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step3400.pt
# Epoch 4 [Rank 0]:  41%|████      | 3501/8539 [30:23<1:09:35,  1.21it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step3500.pt
# Epoch 4 [Rank 0]:  42%|████▏     | 3601/8539 [31:03<1:06:24,  1.24it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step3600.pt
# Epoch 4 [Rank 0]:  43%|████▎     | 3701/8539 [31:43<1:12:41,  1.11it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step3700.pt
# Epoch 4 [Rank 0]:  45%|████▍     | 3801/8539 [32:35<1:14:37,  1.06it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step3800.pt
# Epoch 4 [Rank 0]:  46%|████▌     | 3901/8539 [33:13<53:25,  1.45it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step3900.pt
# Epoch 4 [Rank 0]:  47%|████▋     | 4001/8539 [33:51<49:04,  1.54it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step4000.pt
# Epoch 4 [Rank 0]:  48%|████▊     | 4101/8539 [34:36<1:03:32,  1.16it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step4100.pt
# Epoch 4 [Rank 0]:  49%|████▉     | 4201/8539 [35:26<45:14,  1.60it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step4200.pt
# Epoch 4 [Rank 0]:  50%|█████     | 4301/8539 [36:05<1:10:25,  1.00it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step4300.pt
# Epoch 4 [Rank 0]:  52%|█████▏    | 4401/8539 [36:57<1:05:20,  1.06it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step4400.pt
# Epoch 4 [Rank 0]:  53%|█████▎    | 4501/8539 [37:34<44:19,  1.52it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step4500.pt
# Epoch 4 [Rank 0]:  54%|█████▍    | 4601/8539 [38:11<43:28,  1.51it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step4600.pt
# Epoch 4 [Rank 0]:  55%|█████▌    | 4701/8539 [38:50<48:48,  1.31it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step4700.pt
# Epoch 4 [Rank 0]:  56%|█████▌    | 4801/8539 [39:29<48:03,  1.30it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step4800.pt
# Epoch 4 [Rank 0]:  57%|█████▋    | 4901/8539 [40:20<57:24,  1.06it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step4900.pt
# Epoch 4 [Rank 0]:  59%|█████▊    | 5001/8539 [41:02<39:22,  1.50it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step5000.pt
# Epoch 4 [Rank 0]:  60%|█████▉    | 5101/8539 [41:41<40:51,  1.40it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step5100.pt
# Epoch 4 [Rank 0]:  61%|██████    | 5201/8539 [42:23<34:04,  1.63it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step5200.pt
# Epoch 4 [Rank 0]:  62%|██████▏   | 5301/8539 [43:14<45:31,  1.19it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step5300.pt
# Epoch 4 [Rank 0]:  63%|██████▎   | 5401/8539 [43:55<47:51,  1.09it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step5400.pt
# Epoch 4 [Rank 0]:  64%|██████▍   | 5501/8539 [44:36<30:51,  1.64it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step5500.pt
# Epoch 4 [Rank 0]:  66%|██████▌   | 5601/8539 [45:26<41:16,  1.19it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step5600.pt
# Epoch 4 [Rank 0]:  67%|██████▋   | 5701/8539 [46:05<28:35,  1.65it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step5700.pt
# Epoch 4 [Rank 0]:  68%|██████▊   | 5801/8539 [46:56<29:54,  1.53it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step5800.pt
# Epoch 4 [Rank 0]:  69%|██████▉   | 5901/8539 [47:36<28:11,  1.56it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step5900.pt
# Epoch 4 [Rank 0]:  70%|███████   | 6001/8539 [48:17<26:14,  1.61it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step6000.pt
# Epoch 4 [Rank 0]:  71%|███████▏  | 6101/8539 [48:56<24:56,  1.63it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step6100.pt
# Epoch 4 [Rank 0]:  73%|███████▎  | 6201/8539 [49:38<23:08,  1.68it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step6200.pt
# Epoch 4 [Rank 0]:  74%|███████▍  | 6301/8539 [50:27<25:00,  1.49it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step6300.pt
# Epoch 4 [Rank 0]:  75%|███████▍  | 6401/8539 [51:06<24:28,  1.46it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step6400.pt
# Epoch 4 [Rank 0]:  76%|███████▌  | 6501/8539 [51:45<22:27,  1.51it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step6500.pt
# Epoch 4 [Rank 0]:  77%|███████▋  | 6601/8539 [52:30<30:45,  1.05it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step6600.pt
# Epoch 4 [Rank 0]:  78%|███████▊  | 6701/8539 [53:11<20:36,  1.49it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step6700.pt
# Epoch 4 [Rank 0]:  80%|███████▉  | 6801/8539 [54:03<27:44,  1.04it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step6800.pt
# Epoch 4 [Rank 0]:  81%|████████  | 6901/8539 [54:42<17:07,  1.59it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step6900.pt
# Epoch 4 [Rank 0]:  82%|████████▏ | 7001/8539 [55:26<17:31,  1.46it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step7000.pt
# Epoch 4 [Rank 0]:  83%|████████▎ | 7101/8539 [56:07<15:54,  1.51it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step7100.pt
# Epoch 4 [Rank 0]:  84%|████████▍ | 7201/8539 [56:46<16:20,  1.37it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step7200.pt
# Epoch 4 [Rank 0]:  86%|████████▌ | 7301/8539 [57:28<14:53,  1.39it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step7300.pt
# Epoch 4 [Rank 0]:  87%|████████▋ | 7401/8539 [58:07<12:43,  1.49it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step7400.pt
# Epoch 4 [Rank 0]:  88%|████████▊ | 7501/8539 [58:46<12:09,  1.42it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step7500.pt
# Epoch 4 [Rank 0]:  89%|████████▉ | 7601/8539 [59:39<14:35,  1.07it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step7600.pt
# Epoch 4 [Rank 0]:  90%|█████████ | 7701/8539 [1:00:18<09:21,  1.49it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step7700.pt
# Epoch 4 [Rank 0]:  91%|█████████▏| 7801/8539 [1:00:57<07:54,  1.56it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step7800.pt
# Epoch 4 [Rank 0]:  93%|█████████▎| 7901/8539 [1:01:39<06:26,  1.65it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step7900.pt
# Epoch 4 [Rank 0]:  94%|█████████▎| 8001/8539 [1:02:31<06:33,  1.37it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step8000.pt
# Epoch 4 [Rank 0]:  95%|█████████▍| 8101/8539 [1:03:11<04:51,  1.50it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step8100.pt
# Epoch 4 [Rank 0]:  96%|█████████▌| 8201/8539 [1:04:02<04:24,  1.28it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step8200.pt
# Epoch 4 [Rank 0]:  97%|█████████▋| 8301/8539 [1:04:53<03:03,  1.29it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step8300.pt
# Epoch 4 [Rank 0]:  98%|█████████▊| 8401/8539 [1:05:44<02:09,  1.07it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step8400.pt
# Epoch 4 [Rank 0]: 100%|█████████▉| 8501/8539 [1:06:22<00:26,  1.42it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch4_step8500.pt
# Epoch 4 [Rank 0]: 100%|██████████| 8539/8539 [1:06:37<00:00,  2.14it/s]
#  [Epoch 4] Average Loss: 0.032504
# Epoch 5 [Rank 0]:   0%|          | 1/8539 [00:03<7:16:59,  3.07s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step0.pt
# Epoch 5 [Rank 0]:   1%|          | 101/8539 [00:45<2:05:47,  1.12it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step100.pt
# Epoch 5 [Rank 0]:   2%|▏         | 201/8539 [01:35<1:23:16,  1.67it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step200.pt
# Epoch 5 [Rank 0]:   4%|▎         | 301/8539 [02:50<8:32:53,  3.74s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step300.pt
# Epoch 5 [Rank 0]:   5%|▍         | 401/8539 [04:17<2:25:01,  1.07s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step400.pt
# Epoch 5 [Rank 0]:   6%|▌         | 501/8539 [05:09<2:04:52,  1.07it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step500.pt
# Epoch 5 [Rank 0]:   7%|▋         | 601/8539 [05:51<1:57:27,  1.13it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step600.pt
# Epoch 5 [Rank 0]:   8%|▊         | 701/8539 [06:49<1:05:33,  1.99it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step700.pt
# Epoch 5 [Rank 0]:   9%|▉         | 801/8539 [07:32<1:04:50,  1.99it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step800.pt
# Epoch 5 [Rank 0]:  11%|█         | 901/8539 [08:11<54:58,  2.32it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step900.pt
# Epoch 5 [Rank 0]:  12%|█▏        | 1001/8539 [08:48<47:14,  2.66it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step1000.pt
# Epoch 5 [Rank 0]:  13%|█▎        | 1101/8539 [09:25<46:59,  2.64it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step1100.pt
# Epoch 5 [Rank 0]:  14%|█▍        | 1201/8539 [10:07<52:25,  2.33it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step1200.pt
# Epoch 5 [Rank 0]:  15%|█▌        | 1301/8539 [10:46<45:21,  2.66it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step1300.pt
# Epoch 5 [Rank 0]:  16%|█▋        | 1401/8539 [11:23<43:54,  2.71it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step1400.pt
# Epoch 5 [Rank 0]:  18%|█▊        | 1501/8539 [12:02<45:09,  2.60it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step1500.pt
# Epoch 5 [Rank 0]:  19%|█▊        | 1601/8539 [12:40<47:23,  2.44it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step1600.pt
# Epoch 5 [Rank 0]:  20%|█▉        | 1701/8539 [13:22<52:39,  2.16it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step1700.pt
# Epoch 5 [Rank 0]:  21%|██        | 1801/8539 [13:59<42:19,  2.65it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step1800.pt
# Epoch 5 [Rank 0]:  22%|██▏       | 1901/8539 [14:40<49:08,  2.25it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step1900.pt
# Epoch 5 [Rank 0]:  23%|██▎       | 2001/8539 [15:29<1:01:23,  1.77it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step2000.pt
# Epoch 5 [Rank 0]:  25%|██▍       | 2101/8539 [16:20<54:15,  1.98it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step2100.pt
# Epoch 5 [Rank 0]:  26%|██▌       | 2201/8539 [17:00<44:14,  2.39it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step2200.pt
# Epoch 5 [Rank 0]:  27%|██▋       | 2301/8539 [17:37<43:16,  2.40it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step2300.pt
# Epoch 5 [Rank 0]:  28%|██▊       | 2401/8539 [18:20<46:02,  2.22it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step2400.pt
# Epoch 5 [Rank 0]:  29%|██▉       | 2501/8539 [18:58<37:34,  2.68it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step2500.pt
# Epoch 5 [Rank 0]:  30%|███       | 2601/8539 [19:48<53:55,  1.84it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step2600.pt
# Epoch 5 [Rank 0]:  32%|███▏      | 2701/8539 [20:32<45:33,  2.14it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step2700.pt
# Epoch 5 [Rank 0]:  33%|███▎      | 2801/8539 [21:10<37:17,  2.56it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step2800.pt
# Epoch 5 [Rank 0]:  34%|███▍      | 2901/8539 [21:48<36:33,  2.57it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step2900.pt
# Epoch 5 [Rank 0]:  35%|███▌      | 3001/8539 [22:29<39:05,  2.36it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step3000.pt
# Epoch 5 [Rank 0]:  36%|███▋      | 3101/8539 [23:09<37:06,  2.44it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step3100.pt
# Epoch 5 [Rank 0]:  37%|███▋      | 3201/8539 [24:00<49:34,  1.79it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step3200.pt
# Epoch 5 [Rank 0]:  39%|███▊      | 3301/8539 [24:41<33:34,  2.60it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step3300.pt
# Epoch 5 [Rank 0]:  40%|███▉      | 3401/8539 [25:18<31:59,  2.68it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step3400.pt
# Epoch 5 [Rank 0]:  41%|████      | 3501/8539 [25:57<31:55,  2.63it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step3500.pt
# Epoch 5 [Rank 0]:  42%|████▏     | 3601/8539 [26:33<30:35,  2.69it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step3600.pt
# Epoch 5 [Rank 0]:  43%|████▎     | 3701/8539 [27:17<44:52,  1.80it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step3700.pt
# Epoch 5 [Rank 0]:  45%|████▍     | 3801/8539 [28:09<44:12,  1.79it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step3800.pt
# Epoch 5 [Rank 0]:  46%|████▌     | 3901/8539 [28:46<28:30,  2.71it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step3900.pt
# Epoch 5 [Rank 0]:  47%|████▋     | 4001/8539 [29:23<27:52,  2.71it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step4000.pt
# Epoch 5 [Rank 0]:  48%|████▊     | 4101/8539 [30:01<28:24,  2.60it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step4100.pt
# Epoch 5 [Rank 0]:  49%|████▉     | 4201/8539 [30:52<36:25,  1.98it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step4200.pt
# Epoch 5 [Rank 0]:  50%|█████     | 4301/8539 [32:02<1:30:22,  1.28s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step4300.pt
# Epoch 5 [Rank 0]:  52%|█████▏    | 4401/8539 [32:43<25:39,  2.69it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step4400.pt
# Epoch 5 [Rank 0]:  53%|█████▎    | 4501/8539 [33:34<36:37,  1.84it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step4500.pt
# Epoch 5 [Rank 0]:  54%|█████▍    | 4601/8539 [34:18<29:49,  2.20it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step4600.pt
# Epoch 5 [Rank 0]:  55%|█████▌    | 4701/8539 [34:58<27:43,  2.31it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step4700.pt
# Epoch 5 [Rank 0]:  56%|█████▌    | 4801/8539 [35:39<24:24,  2.55it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step4800.pt
# Epoch 5 [Rank 0]:  57%|█████▋    | 4901/8539 [36:15<21:57,  2.76it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step4900.pt
# Epoch 5 [Rank 0]:  59%|█████▊    | 5001/8539 [37:09<37:49,  1.56it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step5000.pt
# Epoch 5 [Rank 0]:  60%|█████▉    | 5101/8539 [38:04<41:12,  1.39it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step5100.pt
# Epoch 5 [Rank 0]:  61%|██████    | 5201/8539 [38:45<20:49,  2.67it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step5200.pt
# Epoch 5 [Rank 0]:  62%|██████▏   | 5301/8539 [39:23<19:55,  2.71it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step5300.pt
# Epoch 5 [Rank 0]:  63%|██████▎   | 5401/8539 [40:03<19:45,  2.65it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step5400.pt
# Epoch 5 [Rank 0]:  64%|██████▍   | 5501/8539 [40:43<28:01,  1.81it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step5500.pt
# Epoch 5 [Rank 0]:  66%|██████▌   | 5601/8539 [41:35<24:08,  2.03it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step5600.pt
# Epoch 5 [Rank 0]:  67%|██████▋   | 5701/8539 [42:27<25:53,  1.83it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step5700.pt
# Epoch 5 [Rank 0]:  68%|██████▊   | 5801/8539 [43:08<17:43,  2.57it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step5800.pt
# Epoch 5 [Rank 0]:  69%|██████▉   | 5901/8539 [43:46<16:27,  2.67it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step5900.pt
# Epoch 5 [Rank 0]:  70%|███████   | 6001/8539 [44:27<21:23,  1.98it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step6000.pt
# Epoch 5 [Rank 0]:  71%|███████▏  | 6101/8539 [45:07<17:17,  2.35it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step6100.pt
# Epoch 5 [Rank 0]:  73%|███████▎  | 6201/8539 [45:47<16:02,  2.43it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step6200.pt
# Epoch 5 [Rank 0]:  74%|███████▍  | 6301/8539 [46:25<13:52,  2.69it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step6300.pt
# Epoch 5 [Rank 0]:  75%|███████▍  | 6401/8539 [47:36<32:55,  1.08it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step6400.pt
# Epoch 5 [Rank 0]:  76%|███████▌  | 6501/8539 [48:22<14:49,  2.29it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step6500.pt
# Epoch 5 [Rank 0]:  77%|███████▋  | 6601/8539 [49:01<13:56,  2.32it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step6600.pt
# Epoch 5 [Rank 0]:  78%|███████▊  | 6701/8539 [49:51<21:35,  1.42it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step6700.pt
# Epoch 5 [Rank 0]:  80%|███████▉  | 6801/8539 [50:30<10:39,  2.72it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step6800.pt
# Epoch 5 [Rank 0]:  81%|████████  | 6901/8539 [51:06<10:10,  2.68it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step6900.pt
# Epoch 5 [Rank 0]:  82%|████████▏ | 7001/8539 [51:59<14:30,  1.77it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step7000.pt
# Epoch 5 [Rank 0]:  83%|████████▎ | 7101/8539 [52:45<13:23,  1.79it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step7100.pt
# Epoch 5 [Rank 0]:  84%|████████▍ | 7201/8539 [53:22<08:11,  2.72it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step7200.pt
# Epoch 5 [Rank 0]:  86%|████████▌ | 7301/8539 [54:25<12:04,  1.71it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step7300.pt
# Epoch 5 [Rank 0]:  87%|████████▋ | 7401/8539 [55:13<11:57,  1.59it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step7400.pt
# Epoch 5 [Rank 0]:  88%|████████▊ | 7501/8539 [55:54<06:49,  2.54it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step7500.pt
# Epoch 5 [Rank 0]:  89%|████████▉ | 7601/8539 [56:49<11:08,  1.40it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step7600.pt
# Epoch 5 [Rank 0]:  90%|█████████ | 7701/8539 [57:34<06:18,  2.21it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step7700.pt
# Epoch 5 [Rank 0]:  91%|█████████▏| 7801/8539 [58:14<05:16,  2.33it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step7800.pt
# Epoch 5 [Rank 0]:  93%|█████████▎| 7901/8539 [59:01<05:23,  1.97it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step7900.pt
# Epoch 5 [Rank 0]:  94%|█████████▎| 8001/8539 [1:00:02<08:39,  1.04it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step8000.pt
# Epoch 5 [Rank 0]:  95%|█████████▍| 8101/8539 [1:00:45<03:08,  2.32it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step8100.pt
# Epoch 5 [Rank 0]:  96%|█████████▌| 8201/8539 [1:01:29<02:52,  1.95it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step8200.pt
# Epoch 5 [Rank 0]:  97%|█████████▋| 8301/8539 [1:02:07<01:40,  2.36it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step8300.pt
# Epoch 5 [Rank 0]:  98%|█████████▊| 8401/8539 [1:02:58<01:20,  1.71it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step8400.pt
# Epoch 5 [Rank 0]: 100%|█████████▉| 8501/8539 [1:03:39<00:16,  2.27it/s]
#  Saved LoRA-only checkpoint: checkpoints/epoch5_step8500.pt
# Epoch 5 [Rank 0]: 100%|██████████| 8539/8539 [1:03:58<00:00,  2.22it/s]
#  [Epoch 5] Average Loss: 0.032409

# %% [markdown]
# FFine-tuning 10 epoch

# %%
import os
import torch
from tqdm import tqdm
from peft import get_peft_model_state_dict

# ==== Resume Training Settings ====
save_dir = "checkpoints"
resume_path = os.path.join(save_dir, "last_checkpoint.pt")
total_epochs = 8
start_epoch = 0

# Check if checkpoint exists
if os.path.exists(resume_path):
    print(f" Resuming from checkpoint: {resume_path}")
    start_epoch = 5
else:
    print(" Starting fresh training.")

# ==== Step 4: Training Loop + Checkpoint Saving ====
optimizer = torch.optim.Adam(pipe.unet.parameters(), lr=1e-4)
pipe.unet.train()

os.makedirs(save_dir, exist_ok=True)

if os.path.exists(resume_path):
    map_location = {f"cuda:{0}": f"cuda:{local_rank}"}
    lora_state_dict = torch.load(resume_path, map_location=map_location)

    if is_distributed:
        pipe.unet.module.load_state_dict(lora_state_dict, strict=False)
    else:
        pipe.unet.load_state_dict(lora_state_dict, strict=False)

    print(" LoRA adapter weights loaded.")

accumulate_steps = 2
scaler = torch.amp.GradScaler('cuda')

for epoch in range(start_epoch, total_epochs):
    if is_distributed:
        sampler.set_epoch(epoch)
    optimizer.zero_grad()

    running_loss = 0.0  #  Used to track average loss this epoch

    for step, (video, text) in enumerate(tqdm(dataloader, desc=f"Epoch {epoch+1} [Rank {local_rank}]")):
        video = video.to(device)  # [B, T, C, H, W]
        B, T, C, H, W = video.shape

        #  Video frame sampling
        video = sample_segment_frames_batch(video, num_frames=16, method="uniform")
        B, T, C, H, W = video.shape

        #  Text tokenization
        text_inputs = pipe.tokenizer(list(text), return_tensors="pt", padding=True, truncation=True).to(device)
        encoder_hidden_states = pipe.text_encoder(**text_inputs)[0]  # [B, L, D]

        #  VAE encoding
        video_flat = video.view(B * T, C, H, W)
        with torch.no_grad():
            latents_flat = pipe.vae.encode(video_flat).latent_dist.sample()

        latents = latents_flat.view(B, T, -1, H // 8, W // 8) * 0.18215
        latents = latents.permute(0, 2, 1, 3, 4)  # [B, C, T, H, W]

        #  Add noise
        noise = torch.randn_like(latents)
        timesteps = torch.randint(0, 1000, (B,), device=latents.device).long()
        noisy_latents = pipe.scheduler.add_noise(latents, noise, timesteps)

        #  Forward + loss
        with torch.amp.autocast('cuda'):
            noise_pred = pipe.unet(
                noisy_latents,
                timesteps,
                encoder_hidden_states=encoder_hidden_states
            ).sample
            loss = torch.nn.functional.mse_loss(noise_pred, noise) / accumulate_steps

        #  Backward
        scaler.scale(loss).backward()
        running_loss += loss.item()  #  Accumulate epoch loss

        if (step + 1) % accumulate_steps == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        #  Save LoRA adapter weights
        if step % 100 == 0 and local_rank == 0:
            ckpt_path = os.path.join(save_dir, f"epoch{epoch+1}_step{step}.pt")
            lora_state_dict = get_peft_model_state_dict(pipe.unet)
            torch.save(lora_state_dict, ckpt_path)
            torch.save(lora_state_dict, resume_path)
            print(f" Saved LoRA-only checkpoint: {ckpt_path}")

    torch.cuda.empty_cache()

    #  Print epoch average loss (main process only)
    avg_loss = running_loss / len(dataloader)
    if local_rank == 0:
        print(f" [Epoch {epoch+1}] Average Loss: {avg_loss:.6f}")
# Out:
#  Resuming from checkpoint: checkpoints/last_checkpoint.pt
#  LoRA adapter weights loaded.
# Epoch 6 [Rank 0]:   0%|          | 1/500 [00:03<31:04,  3.74s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch6_step0.pt
# Epoch 6 [Rank 0]:  20%|██        | 101/500 [04:00<19:02,  2.86s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch6_step100.pt
# Epoch 6 [Rank 0]:  40%|████      | 201/500 [07:24<12:32,  2.52s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch6_step200.pt
# Epoch 6 [Rank 0]:  60%|██████    | 301/500 [10:47<08:44,  2.64s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch6_step300.pt
# Epoch 6 [Rank 0]:  80%|████████  | 401/500 [14:07<04:07,  2.50s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch6_step400.pt
# Epoch 6 [Rank 0]: 100%|██████████| 500/500 [17:22<00:00,  2.09s/it]
#  [Epoch 6] Average Loss: 0.046027
# Epoch 7 [Rank 0]:   0%|          | 1/500 [00:03<30:57,  3.72s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch7_step0.pt
# Epoch 7 [Rank 0]:  20%|██        | 101/500 [03:27<16:25,  2.47s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch7_step100.pt
# Epoch 7 [Rank 0]:  40%|████      | 201/500 [06:51<12:27,  2.50s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch7_step200.pt
# Epoch 7 [Rank 0]:  60%|██████    | 301/500 [10:08<08:11,  2.47s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch7_step300.pt
# Epoch 7 [Rank 0]:  80%|████████  | 401/500 [14:01<05:39,  3.43s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch7_step400.pt
# Epoch 7 [Rank 0]: 100%|██████████| 500/500 [17:21<00:00,  2.08s/it]
#  [Epoch 7] Average Loss: 0.046965
# Epoch 8 [Rank 0]:   0%|          | 1/500 [00:03<33:10,  3.99s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch8_step0.pt
# Epoch 8 [Rank 0]:  20%|██        | 101/500 [03:34<16:20,  2.46s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch8_step100.pt
# Epoch 8 [Rank 0]:  40%|████      | 201/500 [07:20<12:05,  2.43s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch8_step200.pt
# Epoch 8 [Rank 0]:  60%|██████    | 301/500 [10:49<08:27,  2.55s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch8_step300.pt
# Epoch 8 [Rank 0]:  80%|████████  | 401/500 [14:09<04:07,  2.50s/it]
#  Saved LoRA-only checkpoint: checkpoints/epoch8_step400.pt
# Epoch 8 [Rank 0]: 100%|██████████| 500/500 [17:32<00:00,  2.10s/it]
#  [Epoch 8] Average Loss: 0.046312

# %%
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
import torch
import imageio
import numpy as np
from IPython.display import HTML, Video
from base64 import b64encode

# === Load the base pipeline ===
pipe = DiffusionPipeline.from_pretrained("damo-vilab/text-to-video-ms-1.7b", torch_dtype=torch.float16, variant="fp16")
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.to("cuda")

# === Load your trained LoRA weights ===
lora_weights = torch.load("checkpoints/last_checkpoint.pt")
pipe.unet.load_state_dict(lora_weights, strict=False)  # If trained with DDP, you may need `.module`

# === Inference ===
pipe.enable_model_cpu_offload()
prompt = "crack two eggs into a bowl"
result = pipe(prompt, num_inference_steps=25)
frames = result.frames[0]  # shape: (T, H, W, C)

# === Save video ===
out_path = "uniform_10epoch_egg.mp4"
frames = [(frame * 255).astype(np.uint8) if frame.max() <= 1 else frame.astype(np.uint8) for frame in frames]
imageio.mimsave(out_path, frames, fps=8)

# === Preview video in notebook ===
mp4 = open(out_path, "rb").read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"<video width=512 controls><source src='{data_url}' type='video/mp4'></video>")
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# <video width=512 controls><source src='data:video/mp4;base64,...' type='video/mp4'></video>

# %%
# === Inference ===
pipe.enable_model_cpu_offload()
prompt = "A person is slicing vegetables on a cutting board"
result = pipe(prompt, num_inference_steps=25)
frames = result.frames[0]  # shape: (T, H, W, C)

# === Save video ===
out_path = "uniform_10epoch_vegetable.mp4"
frames = [(frame * 255).astype(np.uint8) if frame.max() <= 1 else frame.astype(np.uint8) for frame in frames]
imageio.mimsave(out_path, frames, fps=8)

# === Video preview ===
mp4 = open(out_path, "rb").read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"<video width=512 controls><source src='{data_url}' type='video/mp4'></video>")
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# <video width=512 controls><source src='data:video/mp4;base64,...' type='video/mp4'></video>

# %%
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
import torch
import imageio
import numpy as np
from IPython.display import HTML, Video
from base64 import b64encode

# === Load the base pipeline ===
pipe = DiffusionPipeline.from_pretrained("damo-vilab/text-to-video-ms-1.7b", torch_dtype=torch.float16, variant="fp16")
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.to("cuda")

# === Load your fine-tuned LoRA weights ===
lora_weights = torch.load("checkpoints/last_checkpoint.pt")
pipe.unet.load_state_dict(lora_weights, strict=False)

# === Inference ===
pipe.enable_model_cpu_offload()
prompt = "crack two eggs into a bowl"
result = pipe(prompt, num_inference_steps=25)
frames = result.frames[0]  # shape: (T, H, W, C)

# === Save video ===
out_path = "finetuned_output.mp4"
frames = [(frame * 255).astype(np.uint8) if frame.max() <= 1 else frame.astype(np.uint8) for frame in frames]
imageio.mimsave(out_path, frames, fps=8)

# === Preview video in notebook ===
mp4 = open(out_path, "rb").read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"<video width=512 controls><source src='{data_url}' type='video/mp4'></video>")
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# <video width=512 controls><source src='data:video/mp4;base64,...' type='video/mp4'></video>

# %%
# === Inference ===
pipe.enable_model_cpu_offload()
prompt = "A person is slicing vegetables on a cutting board"
result = pipe(prompt, num_inference_steps=25)
frames = result.frames[0]  # shape: (T, H, W, C)

# === Save video ===
out_path = "finetuned_output.mp4"
frames = [(frame * 255).astype(np.uint8) if frame.max() <= 1 else frame.astype(np.uint8) for frame in frames]
imageio.mimsave(out_path, frames, fps=8)

# === Preview video in notebook ===
mp4 = open(out_path, "rb").read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"<video width=512 controls><source src='{data_url}' type='video/mp4'></video>")
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# <video width=512 controls><source src='data:video/mp4;base64,...' type='video/mp4'></video>

# %%
# ==== Step 5: Upload Final Model to S3 (Main Process Only) ====
if local_rank == 0:
    s3 = boto3.client(
        's3',
        aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
        aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY")
    )
    final_ckpt = resume_path
    s3_upload_key = "ModelScope_T2V_finetuned/lora_unet_5epoch.pt"
    s3.upload_file(final_ckpt, s3_bucket, s3_upload_key)
    print(f"LoRA weights uploaded to s3://{s3_bucket}/{s3_upload_key}")
# Out:
# LoRA weights uploaded to s3://data298youcook2/ModelScope_T2V_finetuned/lora_unet_5epoch.pt
